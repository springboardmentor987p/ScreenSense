# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("Indian_Kids_Screen_Time.csv")

# %%
df.rename(columns={
    'Avg_Daily_Screen_Time_hr': 'Screen_Time_hr',
    'Primary_Device': 'Device',
    'Urban_or_Rural': 'Location'
}, inplace=True)

# %%
df = df.dropna(subset=['Screen_Time_hr', 'Age'])

# %%
df['Age_Group'] = pd.cut(df['Age'], bins=[0, 8, 12, 17, 20], labels=['5-8', '9-12', '13-17', '18+'])

# %%
sns.set(style="whitegrid", palette="Set2")
plt.rcParams['axes.facecolor'] = '#f7f7f7'
plt.rcParams['figure.facecolor'] = 'white'

# %%
df.tail()
# Out:
#       Age  Gender  Screen_Time_hr      Device  Exceeded_Recommended_Limit  \
# 9707   17    Male            3.26  Smartphone                        True
# 9708   17  Female            4.43  Smartphone                        True
# 9709   16    Male            5.62  Smartphone                        True
# 9710   17    Male            5.60          TV                        True
# 9711   15  Female            6.12          TV                        True
#
#       Educational_to_Recreational_Ratio                   Health_Impacts  \
# 9707                               0.44                       Poor Sleep
# 9708                               0.40                       Poor Sleep
# 9709                               0.39  Poor Sleep, Eye Strain, Anxiety
# 9710                               0.43                       Poor Sleep
# 9711                               0.33                          Anxiety
#
#      Location Age_Group
# 9707    Urban     13-17
# 9708    Rural     13-17
# 9709    Rural     13-17
# 9710    Urban     13-17
# 9711    Urban     13-17

# %%
df.shape
# Out:
# (9712, 9)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Screen_Time_hr', 'Device',
#        'Exceeded_Recommended_Limit', 'Educational_to_Recreational_Ratio',
#        'Health_Impacts', 'Location', 'Age_Group'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Age',
#  'Gender',
#  'Screen_Time_hr',
#  'Device',
#  'Exceeded_Recommended_Limit',
#  'Educational_to_Recreational_Ratio',
#  'Health_Impacts',
#  'Location',
#  'Age_Group']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 9 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Screen_Time_hr                     9712 non-null   float64
#  3   Device                             9712 non-null   object
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   object
#  7   Location                           9712 non-null   object
#  8   Age_Group                          9712 non-null   category
# dtypes: bool(1), category(1), float64(2), int64(1), object(4)
# memory usage: 550.4+ KB

# %%
df.describe()
# Out:
#                Age  Screen_Time_hr  Educational_to_Recreational_Ratio
# count  9712.000000     9712.000000                        9712.000000
# mean     12.979201        4.352837                           0.427226
# std       3.162437        1.718232                           0.073221
# min       8.000000        0.000000                           0.300000
# 25%      10.000000        3.410000                           0.370000
# 50%      13.000000        4.440000                           0.430000
# 75%      16.000000        5.380000                           0.480000
# max      18.000000       13.890000                           0.600000

# %%
df.isnull()
# Out:
#         Age  Gender  Screen_Time_hr  Device  Exceeded_Recommended_Limit  \
# 0     False   False           False   False                       False
# 1     False   False           False   False                       False
# 2     False   False           False   False                       False
# 3     False   False           False   False                       False
# 4     False   False           False   False                       False
# ...     ...     ...             ...     ...                         ...
# 9707  False   False           False   False                       False
# 9708  False   False           False   False                       False
# 9709  False   False           False   False                       False
# 9710  False   False           False   False                       False
# 9711  False   False           False   False                       False
#
#       Educational_to_Recreational_Ratio  Health_Impacts  Location  Age_Group
# 0                                 False           False     False      False
# 1                                 False           False     False      False
# 2                                 False           False     False      False
# 3                                 False            True     False      False
# 4                                 False           False     False      False
# ...                                 ...             ...       ...        ...
# 9707                              False           False     False      False
# 9708                              False           False     False      False
# 9709                              False           False     False      False
# 9710                              False           False     False      False
# 9711                              False           False     False      False
#
# [9712 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Age                                     0
# Gender                                  0
# Screen_Time_hr                          0
# Device                                  0
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3218
# Location                                0
# Age_Group                               0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9707    False
# 9708    False
# 9709    False
# 9710    False
# 9711    False
# Length: 9712, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(44)

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of       Age  Gender  Screen_Time_hr      Device  Exceeded_Recommended_Limit  \
# 0      14    Male            3.99  Smartphone                        True
# 1      11  Female            4.61      Laptop                        True
# 2      18  Female            3.73          TV                        True
# 3      15  Female            1.21      Laptop                       False
# 4      12  Female            5.89  Smartphone                        True
# ...   ...     ...             ...         ...                         ...
# 9707   17    Male            3.26  Smartphone                        True
# 9708   17  Female            4.43  Smartphone                        True
# 9709   16    Male            5.62  Smartphone                        True
# 9710   17    Male            5.60          TV                        True
# 9711   15  Female            6.12          TV                        True
#
#       Educational_to_Recreational_Ratio                   Health_Impacts  \
# 0                                  0.42           Poor Sleep, Eye Strain
# 1                                  0.30                       Poor Sleep
# 2                                  0.32                       Poor Sleep
# 3                                  0.39                              NaN
# 4                                  0.49              Poor Sleep, Anxiety
# ...                                 ...                              ...
# 9707                               0.44                       Poor Sleep
# 9708                               0.40                       Poor Sleep
# 9709                               0.39  Poor Sleep, Eye Strain, Anxiety
# 9710                               0.43                       Poor Sleep
# 9711                               0.33                          Anxiety
#
#      Location Age_Group
# 0       Urban     13-17
# 1       Urban      9-12
# 2       Urban       18+
# 3       Urban     13-17
# 4       Urban      9-12
# ...       ...       ...
# 9707    Urban     13-17
# 9708    Rural     13-17
# 9709    Rural     13-17
# 9710    Urban     13-17
# 9711    Urban     13-17
#
# [9712 rows x 9 columns]>

# %%
df.shape
# Out:
# (9712, 9)

# %%
df.dtypes
# Out:
# Age                                     int64
# Gender                                 object
# Screen_Time_hr                        float64
# Device                                 object
# Exceeded_Recommended_Limit               bool
# Educational_to_Recreational_Ratio     float64
# Health_Impacts                         object
# Location                               object
# Age_Group                            category
# dtype: object

# %%
print(df.columns.tolist())
# Out:
# ['Age', 'Gender', 'Screen_Time_hr', 'Device', 'Exceeded_Recommended_Limit', 'Educational_to_Recreational_Ratio', 'Health_Impacts', 'Location', 'Age_Group']

# %%
df["Device"].unique()
# Out:
# array(['Smartphone', 'Laptop', 'TV', 'Tablet'], dtype=object)

# %%
df[df["Age"] > 12]
# Out:
#       Age  Gender  Screen_Time_hr      Device  Exceeded_Recommended_Limit  \
# 0      14    Male            3.99  Smartphone                        True
# 2      18  Female            3.73          TV                        True
# 3      15  Female            1.21      Laptop                       False
# 5      14  Female            4.88  Smartphone                        True
# 6      17    Male            2.97          TV                       False
# ...   ...     ...             ...         ...                         ...
# 9707   17    Male            3.26  Smartphone                        True
# 9708   17  Female            4.43  Smartphone                        True
# 9709   16    Male            5.62  Smartphone                        True
# 9710   17    Male            5.60          TV                        True
# 9711   15  Female            6.12          TV                        True
#
#       Educational_to_Recreational_Ratio                   Health_Impacts  \
# 0                                  0.42           Poor Sleep, Eye Strain
# 2                                  0.32                       Poor Sleep
# 3                                  0.39                              NaN
# 5                                  0.44                       Poor Sleep
# 6                                  0.48                              NaN
# ...                                 ...                              ...
# 9707                               0.44                       Poor Sleep
# 9708                               0.40                       Poor Sleep
# 9709                               0.39  Poor Sleep, Eye Strain, Anxiety
# 9710                               0.43                       Poor Sleep
# 9711                               0.33                          Anxiety
#
#      Location Age_Group
# 0       Urban     13-17
# 2       Urban       18+
# 3       Urban     13-17
# 5       Urban     13-17
# 6       Rural     13-17
# ...       ...       ...
# 9707    Urban     13-17
# 9708    Rural     13-17
# 9709    Rural     13-17
# 9710    Urban     13-17
# 9711    Urban     13-17
#
# [5305 rows x 9 columns]

# %%
df[df["Device"] == "Smartphone"]
# Out:
#       Age  Gender  Screen_Time_hr      Device  Exceeded_Recommended_Limit  \
# 0      14    Male            3.99  Smartphone                        True
# 4      12  Female            5.89  Smartphone                        True
# 5      14  Female            4.88  Smartphone                        True
# 12     12    Male            4.59  Smartphone                        True
# 14     15    Male            6.15  Smartphone                        True
# ...   ...     ...             ...         ...                         ...
# 9703    9    Male            6.62  Smartphone                        True
# 9706    8    Male            4.84  Smartphone                        True
# 9707   17    Male            3.26  Smartphone                        True
# 9708   17  Female            4.43  Smartphone                        True
# 9709   16    Male            5.62  Smartphone                        True
#
#       Educational_to_Recreational_Ratio                   Health_Impacts  \
# 0                                  0.42           Poor Sleep, Eye Strain
# 4                                  0.49              Poor Sleep, Anxiety
# 5                                  0.44                       Poor Sleep
# 12                                 0.43                       Poor Sleep
# 14                                 0.40                       Poor Sleep
# ...                                 ...                              ...
# 9703                               0.48                       Poor Sleep
# 9706                               0.55                              NaN
# 9707                               0.44                       Poor Sleep
# 9708                               0.40                       Poor Sleep
# 9709                               0.39  Poor Sleep, Eye Strain, Anxiety
#
#      Location Age_Group
# 0       Urban     13-17
# 4       Urban      9-12
# 5       Urban     13-17
# 12      Urban      9-12
# 14      Urban     13-17
# ...       ...       ...
# 9703    Rural      9-12
# 9706    Rural       5-8
# 9707    Urban     13-17
# 9708    Rural     13-17
# 9709    Rural     13-17
#
# [4568 rows x 9 columns]

# %%
df.sort_values("Age")
# Out:
#       Age  Gender  Screen_Time_hr      Device  Exceeded_Recommended_Limit  \
# 28      8    Male            0.31  Smartphone                       False
# 24      8    Male            3.19      Tablet                        True
# 7941    8  Female            9.17          TV                        True
# 9691    8  Female            2.26          TV                        True
# 9690    8  Female            5.57  Smartphone                        True
# ...   ...     ...             ...         ...                         ...
# 2      18  Female            3.73          TV                        True
# 30     18    Male            4.45  Smartphone                        True
# 29     18    Male            5.13          TV                        True
# 9      18    Male            3.24      Tablet                        True
# 10     18    Male            3.53      Tablet                        True
#
#       Educational_to_Recreational_Ratio                     Health_Impacts  \
# 28                                 0.51                                NaN
# 24                                 0.54  Poor Sleep, Anxiety, Obesity Risk
# 7941                               0.55                         Poor Sleep
# 9691                               0.59                                NaN
# 9690                               0.44                         Eye Strain
# ...                                 ...                                ...
# 2                                  0.32                         Poor Sleep
# 30                                 0.48                         Eye Strain
# 29                                 0.43           Poor Sleep, Obesity Risk
# 9                                  0.48           Poor Sleep, Obesity Risk
# 10                                 0.44                         Poor Sleep
#
#      Location Age_Group
# 28      Urban       5-8
# 24      Urban       5-8
# 7941    Rural       5-8
# 9691    Urban       5-8
# 9690    Rural       5-8
# ...       ...       ...
# 2       Urban       18+
# 30      Urban       18+
# 29      Urban       18+
# 9       Urban       18+
# 10      Rural       18+
#
# [9712 rows x 9 columns]

# %%
df.sort_values("Age", ascending=False)
# Out:
#       Age  Gender  Screen_Time_hr      Device  Exceeded_Recommended_Limit  \
# 9683   18    Male            5.11  Smartphone                        True
# 2      18  Female            3.73          TV                        True
# 30     18    Male            4.45  Smartphone                        True
# 9693   18  Female            7.54  Smartphone                        True
# 9      18    Male            3.24      Tablet                        True
# ...   ...     ...             ...         ...                         ...
# 9706    8    Male            4.84  Smartphone                        True
# 1535    8  Female            1.21      Tablet                       False
# 9690    8  Female            5.57  Smartphone                        True
# 9689    8    Male            1.90      Tablet                       False
# 9667    8  Female            0.89      Tablet                       False
#
#       Educational_to_Recreational_Ratio            Health_Impacts Location  \
# 9683                               0.39              Obesity Risk    Rural
# 2                                  0.32                Poor Sleep    Urban
# 30                                 0.48                Eye Strain    Urban
# 9693                               0.36                Poor Sleep    Urban
# 9                                  0.48  Poor Sleep, Obesity Risk    Urban
# ...                                 ...                       ...      ...
# 9706                               0.55                       NaN    Rural
# 1535                               0.40                       NaN    Rural
# 9690                               0.44                Eye Strain    Rural
# 9689                               0.57                       NaN    Urban
# 9667                               0.52                       NaN    Urban
#
#      Age_Group
# 9683       18+
# 2          18+
# 30         18+
# 9693       18+
# 9          18+
# ...        ...
# 9706       5-8
# 1535       5-8
# 9690       5-8
# 9689       5-8
# 9667       5-8
#
# [9712 rows x 9 columns]

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Age_Group', y='Screen_Time_hr', data=df, estimator=np.mean)
plt.title('Average Daily Screentime by Age Group', fontsize=14, weight='bold')
plt.xlabel('Age Group')
plt.ylabel('Average Screen Time (Hours)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3184035694.py in <cell line: 0>()
# ----> 1 plt.figure(figsize=(8,5))
#       2 sns.barplot(x='Age_Group', y='Screen_Time_hr', data=df, estimator=np.mean)
#       3 plt.title('Average Daily Screentime by Age Group', fontsize=14, weight='bold')
#       4 plt.xlabel('Age Group')
#       5 plt.ylabel('Average Screen Time (Hours)')
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Age_Group', y='Screen_Time_hr', data=df, estimator=np.mean)
plt.title('Average Daily Screentime by Age Group', fontsize=14, weight='bold')
plt.xlabel('Age Group')
plt.ylabel('Average Screen Time (Hours)')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Location', y='Screen_Time_hr', data=df, estimator=np.mean)
plt.title('Average Screentime by Location Type', fontsize=14, weight='bold')
plt.xlabel('Location')
plt.ylabel('Average Screen Time (Hours)')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Device', y='Screen_Time_hr', data=df, estimator=np.mean)
plt.title('Average Screentime by Device Type', fontsize=14, weight='bold')
plt.xlabel('Device Type')
plt.ylabel('Average Screen Time (Hours)')
plt.xticks(rotation=30)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Exceeded_Recommended_Limit', y='Screen_Time_hr', data=df, estimator=np.mean)
plt.title('Screentime vs Recommended Limit', fontsize=14, weight='bold')
plt.xlabel('Exceeded Limit (True/False)')
plt.ylabel('Average Screen Time (Hours)')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(y='Health_Impacts', data=df, order=df['Health_Impacts'].value_counts().index)
plt.title('Common Health Impacts Due to Screentime', fontsize=14, weight='bold')
plt.xlabel('Count')
plt.ylabel('Health Impact')
plt.show()

# %%
plt.figure(figsize=(7,7))
device_counts = df['Device'].value_counts()
plt.pie(device_counts, labels=device_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("Set2"))
plt.title('Device Usage Distribution', fontsize=14, weight='bold')
plt.show()

# %%
plt.figure(figsize=(6,5))
numeric_df = df.select_dtypes(include=['float64', 'int64'])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap', fontsize=14, weight='bold')
plt.show()

# %% [markdown]
# ____RECOMENDATION SYSTEM_____

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load sample data
df = pd.read_csv("Indian_Kids_Screen_Time.csv")

# Plot average daily usage by age group and gender
sns.barplot(data=df, x='Age', y='Avg_Daily_Screen_Time_hr', hue='Gender')
plt.title("Average Daily Screen Time by Age and Gender")
plt.show()

# %%
avg = df['Avg_Daily_Screen_Time_hr'].mean()
print(avg)
# Out:
# 4.0

# %%
df = pd.read_csv("Indian_Kids_Screen_Time.csv")
df[df['Avg_Daily_Screen_Time_hr'] > avg].value_counts()
# Out:
# Age  Gender  Avg_Daily_Screen_Time_hr  Primary_Device  Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  Health_Impacts            Urban_or_Rural
# 8    Female  4.84                      Smartphone      True                        0.46                               Poor Sleep                Rural             2
# 9    Female  4.44                      TV              True                        0.50                               Poor Sleep                Urban             2
# 16   Female  4.42                      Laptop          True                        0.35                               Poor Sleep, Anxiety       Urban             2
# 18   Male    5.98                      Smartphone      True                        0.49                               Poor Sleep, Eye Strain    Urban             2
# 15   Male    4.40                      Smartphone      True                        0.38                               Poor Sleep, Obesity Risk  Urban             1
#                                                                                                                                                                  ..
# 12   Female  5.07                      Smartphone      True                        0.34                               Anxiety                   Urban             1
#              5.06                      TV              True                        0.41                               Anxiety                   Rural             1
#                                        Smartphone      True                        0.33                               Poor Sleep                Urban             1
#              5.05                      Smartphone      True                        0.41                               Poor Sleep, Eye Strain    Urban             1
#              5.14                      Smartphone      True                        0.40                               Anxiety                   Urban             1
# Name: count, Length: 4841, dtype: int64

# %%
df[df['Exceeded_Recommended_Limit'] == False].sort_values(by='Avg_Daily_Screen_Time_hr' , ascending=False)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 9029   12    Male                       3.0     Smartphone
# 4451   14  Female                       3.0         Tablet
# 2840   14  Female                       3.0     Smartphone
# 987    12  Female                       3.0     Smartphone
# 8793   18  Female                       3.0         Laptop
# ...   ...     ...                       ...            ...
# 4703   10  Female                       0.0             TV
# 4693    8  Female                       0.0     Smartphone
# 4690   10    Male                       0.0         Tablet
# 4881    9    Male                       0.0             TV
# 322     8  Female                       0.0     Smartphone
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 9029                       False                               0.49
# 4451                       False                               0.44
# 2840                       False                               0.36
# 987                        False                               0.36
# 8793                       False                               0.49
# ...                          ...                                ...
# 4703                       False                               0.47
# 4693                       False                               0.50
# 4690                       False                               0.58
# 4881                       False                               0.47
# 322                        False                               0.55
#
#      Health_Impacts Urban_or_Rural
# 9029            NaN          Urban
# 4451            NaN          Urban
# 2840            NaN          Urban
# 987             NaN          Rural
# 8793            NaN          Rural
# ...             ...            ...
# 4703            NaN          Urban
# 4693            NaN          Rural
# 4690            NaN          Rural
# 4881            NaN          Urban
# 322             NaN          Urban
#
# [1411 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Avg_Daily_Screen_Time_hr', 'Primary_Device',
#        'Exceeded_Recommended_Limit', 'Educational_to_Recreational_Ratio',
#        'Health_Impacts', 'Urban_or_Rural'],
#       dtype='object')

# %%
df.groupby('Exceeded_Recommended_Limit', as_index=False)['Avg_Daily_Screen_Time_hr'].mean()
# Out:
#    Exceeded_Recommended_Limit  Avg_Daily_Screen_Time_hr
# 0                       False                  1.581751
# 1                        True                  4.823865

# %%
df[df['Avg_Daily_Screen_Time_hr'] > avg].value_counts()
# Out:
# Age  Gender  Avg_Daily_Screen_Time_hr  Primary_Device  Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  Health_Impacts            Urban_or_Rural
# 8    Female  4.84                      Smartphone      True                        0.46                               Poor Sleep                Rural             2
# 9    Female  4.44                      TV              True                        0.50                               Poor Sleep                Urban             2
# 16   Female  4.42                      Laptop          True                        0.35                               Poor Sleep, Anxiety       Urban             2
# 18   Male    5.98                      Smartphone      True                        0.49                               Poor Sleep, Eye Strain    Urban             2
# 15   Male    4.40                      Smartphone      True                        0.38                               Poor Sleep, Obesity Risk  Urban             1
#                                                                                                                                                                  ..
# 12   Female  5.07                      Smartphone      True                        0.34                               Anxiety                   Urban             1
#              5.06                      TV              True                        0.41                               Anxiety                   Rural             1
#                                        Smartphone      True                        0.33                               Poor Sleep                Urban             1
#              5.05                      Smartphone      True                        0.41                               Poor Sleep, Eye Strain    Urban             1
#              5.14                      Smartphone      True                        0.40                               Anxiety                   Urban             1
# Name: count, Length: 4841, dtype: int64

# %%
df[df['Exceeded_Recommended_Limit'] == True].sort_values(by='Avg_Daily_Screen_Time_hr' , ascending=True)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 8152    8  Female                      2.01     Smartphone
# 8532    9    Male                      2.01             TV
# 356     8    Male                      2.02     Smartphone
# 3236    9  Female                      2.02     Smartphone
# 696     8  Female                      2.03             TV
# ...   ...     ...                       ...            ...
# 1321   10  Female                     12.09         Tablet
# 1870   10    Male                     12.40     Smartphone
# 1769    9    Male                     12.80             TV
# 934    10  Female                     13.01     Smartphone
# 4298   10  Female                     13.89     Smartphone
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 8152                        True                               0.60
# 8532                        True                               0.54
# 356                         True                               0.57
# 3236                        True                               0.40
# 696                         True                               0.47
# ...                          ...                                ...
# 1321                        True                               0.45
# 1870                        True                               0.52
# 1769                        True                               0.56
# 934                         True                               0.57
# 4298                        True                               0.58
#
#            Health_Impacts Urban_or_Rural
# 8152                  NaN          Urban
# 8532                  NaN          Urban
# 356                   NaN          Urban
# 3236                  NaN          Urban
# 696                   NaN          Rural
# ...                   ...            ...
# 1321           Poor Sleep          Urban
# 1870                  NaN          Urban
# 1769  Eye Strain, Anxiety          Rural
# 934   Poor Sleep, Anxiety          Urban
# 4298  Eye Strain, Anxiety          Urban
#
# [8301 rows x 8 columns]

# %%
df['Avg_Daily_Screen_Time_hr'].value_counts()
# Out:
# Avg_Daily_Screen_Time_hr
# 0.00     226
# 4.93      41
# 4.32      39
# 4.03      39
# 4.96      39
#         ...
# 7.84       1
# 8.54       1
# 10.18      1
# 8.61       1
# 7.47       1
# Name: count, Length: 899, dtype: int64

# %%
age_group_avg = df.groupby('Age')['Avg_Daily_Screen_Time_hr'].mean()
age_group_avg
# Out:
# Age
# 8     3.988925
# 9     3.932181
# 10    3.851425
# 11    4.497263
# 12    4.554348
# 13    4.500967
# 14    4.514821
# 15    4.441725
# 16    4.551781
# 17    4.555397
# 18    4.503976
# Name: Avg_Daily_Screen_Time_hr, dtype: float64

# %%
device_avg = df.groupby('Primary_Device')['Avg_Daily_Screen_Time_hr'].mean()
device_avg
# Out:
# Primary_Device
# Laptop        4.459086
# Smartphone    4.388925
# TV            4.287752
# Tablet        4.226005
# Name: Avg_Daily_Screen_Time_hr, dtype: float64

# %%
above_avg_devices = device_avg[device_avg > avg]
above_avg_devices
# Out:
# Primary_Device
# Laptop        4.459086
# Smartphone    4.388925
# TV            4.287752
# Tablet        4.226005
# Name: Avg_Daily_Screen_Time_hr, dtype: float64

# %%
gender_avg = df.groupby('Gender')['Avg_Daily_Screen_Time_hr'].mean()
print(gender_avg)
# Out:
# Gender
# Female    4.327021
# Male      4.377754
# Name: Avg_Daily_Screen_Time_hr, dtype: float64

# %%
age_group_avg=df.groupby('Age')['Avg_Daily_Screen_Time_hr'].mean()
print(age_group_avg)
# Out:
# Age
# 8     3.988925
# 9     3.932181
# 10    3.851425
# 11    4.497263
# 12    4.554348
# 13    4.500967
# 14    4.514821
# 15    4.441725
# 16    4.551781
# 17    4.555397
# 18    4.503976
# Name: Avg_Daily_Screen_Time_hr, dtype: float64

# %%
device_gender_avg=df.groupby(['Primary_Device','Gender'])['Avg_Daily_Screen_Time_hr'].mean()
print(device_gender_avg)
# Out:
# Primary_Device  Gender
# Laptop          Female    4.481066
#                 Male      4.435549
# Smartphone      Female    4.332350
#                 Male      4.442463
# TV              Female    4.283465
#                 Male      4.291868
# Tablet          Female    4.203407
#                 Male      4.247035
# Name: Avg_Daily_Screen_Time_hr, dtype: float64

# %%
top_device=df.groupby('Primary_Device')['Avg_Daily_Screen_Time_hr'].mean().idxmax()
print("Device with highest screen time:",top_device)
# Out:
# Device with highest screen time: Laptop

# %%
avg_screen_time = df['Avg_Daily_Screen_Time_hr'].mean()
above_avg = df[df['Avg_Daily_Screen_Time_hr'] > avg_screen_time]
below_avg = df[df['Avg_Daily_Screen_Time_hr'] <= avg_screen_time]

print("Above average users:", len(above_avg))
print("Below average users:", len(below_avg))
# Out:
# Above average users: 5048
# Below average users: 4664

# %%
location_avg = df.groupby('Urban_or_Rural')['Avg_Daily_Screen_Time_hr'].mean()
print(location_avg)
# Out:
# Urban_or_Rural
# Rural    4.373702
# Urban    4.344123
# Name: Avg_Daily_Screen_Time_hr, dtype: float64

# %%
limit_avg = df.groupby('Exceeded_Recommended_Limit')['Avg_Daily_Screen_Time_hr'].mean()
print(limit_avg)
# Out:
# Exceeded_Recommended_Limit
# False    1.581751
# True     4.823865
# Name: Avg_Daily_Screen_Time_hr, dtype: float64

# %%
gender_limit = df.groupby(['Gender', 'Exceeded_Recommended_Limit']).size().unstack()
print(gender_limit)
# Out:
# Exceeded_Recommended_Limit  False  True
# Gender
# Female                        745   4025
# Male                          666   4276

# %%
correlation = df['Avg_Daily_Screen_Time_hr'].corr(df['Educational_to_Recreational_Ratio'])
print("Correlation:", correlation)
# Out:
# Correlation: -0.08755222315597143

# %%
device_ratio = df.groupby('Primary_Device')['Educational_to_Recreational_Ratio'].mean()
print(device_ratio)
# Out:
# Primary_Device
# Laptop        0.399002
# Smartphone    0.422077
# TV            0.443703
# Tablet        0.446005
# Name: Educational_to_Recreational_Ratio, dtype: float64

# %%
limit_per_device = (
    df.groupby('Primary_Device')['Exceeded_Recommended_Limit']
    .value_counts(normalize=True)
    .unstack()
    * 100
)
print(limit_per_device)
# Out:
# Exceeded_Recommended_Limit      False      True
# Primary_Device
# Laptop                      11.025820  88.974180
# Smartphone                  13.550788  86.449212
# TV                          16.164053  83.835947
# Tablet                      18.954248  81.045752

# %%
health_by_gender = df.groupby('Gender')['Health_Impacts'].value_counts().unstack().fillna(0)
print(health_by_gender)
# Out:
# Health_Impacts  Anxiety  Anxiety, Obesity Risk  Eye Strain  \
# Gender
# Female              186                     35         324
# Male                199                     34         320
#
# Health_Impacts  Eye Strain, Anxiety  Eye Strain, Anxiety, Obesity Risk  \
# Gender
# Female                           68                                 16
# Male                             67                                 19
#
# Health_Impacts  Eye Strain, Obesity Risk  Obesity Risk  Poor Sleep  \
# Gender
# Female                                53           103        1117
# Male                                  53           149        1151
#
# Health_Impacts  Poor Sleep, Anxiety  Poor Sleep, Anxiety, Obesity Risk  \
# Gender
# Female                          294                                 45
# Male                            314                                 33
#
# Health_Impacts  Poor Sleep, Eye Strain  Poor Sleep, Eye Strain, Anxiety  \
# Gender
# Female                             480                              119
# Male                               499                              139
#
# Health_Impacts  Poor Sleep, Eye Strain, Anxiety, Obesity Risk  \
# Gender
# Female                                                     20
# Male                                                       17
#
# Health_Impacts  Poor Sleep, Eye Strain, Obesity Risk  Poor Sleep, Obesity Risk
# Gender
# Female                                            83                       209
# Male                                             105                       243

# %%
health_time = df.groupby('Health_Impacts')['Avg_Daily_Screen_Time_hr'].mean().sort_values(ascending=False)
print(health_time)
# Out:
# Health_Impacts
# Eye Strain, Anxiety                              5.081185
# Poor Sleep, Anxiety, Obesity Risk                5.060641
# Poor Sleep, Obesity Risk                         5.015376
# Eye Strain, Anxiety, Obesity Risk                4.993429
# Poor Sleep                                       4.955445
# Eye Strain, Obesity Risk                         4.949811
# Poor Sleep, Eye Strain, Anxiety                  4.911667
# Obesity Risk                                     4.911151
# Poor Sleep, Anxiety                              4.906283
# Anxiety                                          4.903403
# Poor Sleep, Eye Strain                           4.883207
# Poor Sleep, Eye Strain, Obesity Risk             4.818617
# Eye Strain                                       4.809301
# Anxiety, Obesity Risk                            4.648841
# Poor Sleep, Eye Strain, Anxiety, Obesity Risk    4.548378
# Name: Avg_Daily_Screen_Time_hr, dtype: float64

# %%
limit_by_location = (
    df.groupby('Urban_or_Rural')['Exceeded_Recommended_Limit']
    .value_counts(normalize=True)
    .unstack()
    * 100
)
print(limit_by_location)
# Out:
# Exceeded_Recommended_Limit      False      True
# Urban_or_Rural
# Rural                       14.645229  85.354771
# Urban                       14.479638  85.520362

# %%
device_health = df.groupby(['Primary_Device', 'Health_Impacts'])['Avg_Daily_Screen_Time_hr'].mean()
print(device_health)
# Out:
# Primary_Device  Health_Impacts
# Laptop          Anxiety                                          4.687419
#                 Anxiety, Obesity Risk                            4.487273
#                 Eye Strain                                       4.692871
#                 Eye Strain, Anxiety                              5.024286
#                 Eye Strain, Anxiety, Obesity Risk                4.722857
#                 Eye Strain, Obesity Risk                         4.783125
#                 Obesity Risk                                     5.031892
#                 Poor Sleep                                       4.711405
#                 Poor Sleep, Anxiety                              4.614074
#                 Poor Sleep, Anxiety, Obesity Risk                5.156000
#                 Poor Sleep, Eye Strain                           4.683176
#                 Poor Sleep, Eye Strain, Anxiety                  4.782308
#                 Poor Sleep, Eye Strain, Anxiety, Obesity Risk    4.265000
#                 Poor Sleep, Eye Strain, Obesity Risk             4.345200
#                 Poor Sleep, Obesity Risk                         4.756852
# Smartphone      Anxiety                                          4.925833
#                 Anxiety, Obesity Risk                            4.746176
#                 Eye Strain                                       4.805961
#                 Eye Strain, Anxiety                              5.153492
#                 Eye Strain, Anxiety, Obesity Risk                4.818421
#                 Eye Strain, Obesity Risk                         4.971579
#                 Obesity Risk                                     4.880985
#                 Poor Sleep                                       4.908535
#                 Poor Sleep, Anxiety                              4.911029
#                 Poor Sleep, Anxiety, Obesity Risk                4.765429
#                 Poor Sleep, Eye Strain                           4.880959
#                 Poor Sleep, Eye Strain, Anxiety                  4.830488
#                 Poor Sleep, Eye Strain, Anxiety, Obesity Risk    4.902941
#                 Poor Sleep, Eye Strain, Obesity Risk             4.826392
#                 Poor Sleep, Obesity Risk                         5.013122
# TV              Anxiety                                          5.142233
#                 Anxiety, Obesity Risk                            4.493125
#                 Eye Strain                                       4.834941
#                 Eye Strain, Anxiety                              5.330800
#                 Eye Strain, Anxiety, Obesity Risk                5.573333
#                 Eye Strain, Obesity Risk                         4.750870
#                 Obesity Risk                                     4.905614
#                 Poor Sleep                                       5.092917
#                 Poor Sleep, Anxiety                              5.023974
#                 Poor Sleep, Anxiety, Obesity Risk                5.567647
#                 Poor Sleep, Eye Strain                           4.944976
#                 Poor Sleep, Eye Strain, Anxiety                  5.166774
#                 Poor Sleep, Eye Strain, Anxiety, Obesity Risk    4.248333
#                 Poor Sleep, Eye Strain, Obesity Risk             4.871429
#                 Poor Sleep, Obesity Risk                         5.091453
# Tablet          Anxiety                                          4.522250
#                 Anxiety, Obesity Risk                            4.768750
#                 Eye Strain                                       4.936970
#                 Eye Strain, Anxiety                              4.596842
#                 Eye Strain, Obesity Risk                         5.550000
#                 Obesity Risk                                     4.904615
#                 Poor Sleep                                       5.178376
#                 Poor Sleep, Anxiety                              5.068571
#                 Poor Sleep, Anxiety, Obesity Risk                5.086364
#                 Poor Sleep, Eye Strain                           5.085000
#                 Poor Sleep, Eye Strain, Anxiety                  4.888529
#                 Poor Sleep, Eye Strain, Anxiety, Obesity Risk    4.200000
#                 Poor Sleep, Eye Strain, Obesity Risk             5.187917
#                 Poor Sleep, Obesity Risk                         5.108000
# Name: Avg_Daily_Screen_Time_hr, dtype: float64

# %%
data = {
    'Age': [15, 25, 35, 45, 55],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'],
    'Avg_Daily_Screen_Time_hr': [5, 6, 4, 3, 2],
    'Primary_Device': ['Phone', 'Laptop', 'Tablet', 'Phone', 'Laptop'],
    'Exceeded_Recommended_Limit': ['Yes', 'Yes', 'No', 'No', 'No'],
    'Educational_to_Recreational_Ratio': [0.4, 0.5, 0.8, 0.9, 1.0],
    'Health_Impacts': ['Eye strain', 'Poor sleep', 'None', 'None', 'None'],
    'Urban_or_Rural': ['Urban', 'Urban', 'Rural', 'Urban', 'Rural']
}

df = pd.DataFrame(data)


def get_recommendation(age, gender, avg_screen_time, primary_device, urban_or_rural):
    recommendations = []

    # 1. General health-based recommendation
    if avg_screen_time > 4:
        recommendations.append("⚠️ Your average screen time is higher than recommended (4 hours). Try reducing non-essential usage.")
    else:
        recommendations.append("✅ Your screen time is within a healthy range. Keep it up!")

    # 2. Educational vs recreational ratio insights
    avg_ratio = df['Educational_to_Recreational_Ratio'].mean()
    if avg_screen_time > 4 and avg_ratio < 0.6:
        recommendations.append("📘 Consider dedicating more screen time to educational or productive activities.")

    # 3. Age-specific recommendation
    if age < 18:
        recommendations.append("👦 Teen users should limit screen time to under 3 hours per day for better sleep and focus.")
    elif 18 <= age <= 35:
        recommendations.append("👩‍💻 Maintain a balance between work and leisure screen time. Avoid using devices right before sleep.")
    else:
        recommendations.append("🧑‍🦳 Take regular breaks every 30 minutes to avoid eye strain.")

    # 4. Gender-based insight (example trend)
    gender_avg = df[df['Gender'] == gender]['Avg_Daily_Screen_Time_hr'].mean()
    recommendations.append(f"📊 Average screen time for {gender}s in your dataset is {gender_avg:.1f} hours per day.")

    # 5. Device-based tip
    if primary_device.lower() == "phone":
        recommendations.append("📱 Try enabling app timers or grayscale mode to reduce excessive phone usage.")
    elif primary_device.lower() == "laptop":
        recommendations.append("💻 Use blue light filters and take short breaks every hour.")
    else:
        recommendations.append("🖥️ Adjust brightness and posture to avoid neck and eye strain.")

    # 6. Urban vs Rural lifestyle insights
    if urban_or_rural.lower() == "urban":
        recommendations.append("🏙️ Urban users often experience digital overload — consider tech-free time outdoors.")
    else:
        recommendations.append("🌄 Rural users often have balanced screen habits — keep maintaining that lifestyle!")

    return recommendations



try:
    age = int(input("Enter your age: "))
    gender = input("Enter your gender (Male/Female): ").capitalize()
    avg_screen_time = float(input("Enter your average daily screen time (in hours): "))
    primary_device = input("Enter your primary device (Phone/Laptop/Tablet): ")
    urban_or_rural = input("Do you live in an Urban or Rural area?: ")

    print("\n=== Personalized Recommendations ===")
    user_recs = get_recommendation(age, gender, avg_screen_time, primary_device, urban_or_rural)
    for rec in user_recs:
        print("-", rec)

except Exception as e:
    print("⚠️ Error:", e)
# Out:
# Enter your age: 7
# Enter your gender (Male/Female): F
# Enter your average daily screen time (in hours): 5
# Enter your primary device (Phone/Laptop/Tablet): phone
# Do you live in an Urban or Rural area?: urban
#
# === Personalized Recommendations ===
# - ⚠️ Your average screen time is higher than recommended (4 hours). Try reducing non-essential usage.
# - 👦 Teen users should limit screen time to under 3 hours per day for better sleep and focus.
# - 📊 Average screen time for Fs in your dataset is nan hours per day.
# - 📱 Try enabling app timers or grayscale mode to reduce excessive phone usage.
# - 🏙️ Urban users often experience digital overload — consider tech-free time outdoors.
