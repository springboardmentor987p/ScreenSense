# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Indian_Kids_Screen_Time.csv")
df.head()
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban
# 3                     NaN          Urban
# 4     Poor Sleep, Anxiety          Urban

# %%
df.tail()
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 9707                        True                               0.44
# 9708                        True                               0.40
# 9709                        True                               0.39
# 9710                        True                               0.43
# 9711                        True                               0.33
#
#                        Health_Impacts Urban_or_Rural
# 9707                       Poor Sleep          Urban
# 9708                       Poor Sleep          Rural
# 9709  Poor Sleep, Eye Strain, Anxiety          Rural
# 9710                       Poor Sleep          Urban
# 9711                          Anxiety          Urban

# %%
df.shape
# Out:
# (9712, 8)

# %%
df.columns.tolist()
# Out:
# ['Age',
#  'Gender',
#  'Avg_Daily_Screen_Time_hr',
#  'Primary_Device',
#  'Exceeded_Recommended_Limit',
#  'Educational_to_Recreational_Ratio',
#  'Health_Impacts',
#  'Urban_or_Rural']

# %%
df.dtypes
# Out:
# Age                                    int64
# Gender                                object
# Avg_Daily_Screen_Time_hr             float64
# Primary_Device                        object
# Exceeded_Recommended_Limit              bool
# Educational_to_Recreational_Ratio    float64
# Health_Impacts                        object
# Urban_or_Rural                        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   object
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   object
#  7   Urban_or_Rural                     9712 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 540.7+ KB

# %%
df.describe()
# Out:
#                Age  Avg_Daily_Screen_Time_hr  \
# count  9712.000000               9712.000000
# mean     12.979201                  4.352837
# std       3.162437                  1.718232
# min       8.000000                  0.000000
# 25%      10.000000                  3.410000
# 50%      13.000000                  4.440000
# 75%      16.000000                  5.380000
# max      18.000000                 13.890000
#
#        Educational_to_Recreational_Ratio
# count                        9712.000000
# mean                            0.427226
# std                             0.073221
# min                             0.300000
# 25%                             0.370000
# 50%                             0.430000
# 75%                             0.480000
# max                             0.600000

# %%
df.isnull().sum()
# Out:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                          0
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3218
# Urban_or_Rural                          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(44)

# %%
df.drop_duplicates()
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# 2                           True                               0.32
# 3                          False                               0.39
# 4                           True                               0.49
# ...                          ...                                ...
# 9707                        True                               0.44
# 9708                        True                               0.40
# 9709                        True                               0.39
# 9710                        True                               0.43
# 9711                        True                               0.33
#
#                        Health_Impacts Urban_or_Rural
# 0              Poor Sleep, Eye Strain          Urban
# 1                          Poor Sleep          Urban
# 2                          Poor Sleep          Urban
# 3                                 NaN          Urban
# 4                 Poor Sleep, Anxiety          Urban
# ...                               ...            ...
# 9707                       Poor Sleep          Urban
# 9708                       Poor Sleep          Rural
# 9709  Poor Sleep, Eye Strain, Anxiety          Rural
# 9710                       Poor Sleep          Urban
# 9711                          Anxiety          Urban
#
# [9668 rows x 8 columns]

# %%
df.shape
# Out:
# (9712, 8)

# %%
df.dtypes
# Out:
# Age                                    int64
# Gender                                object
# Avg_Daily_Screen_Time_hr             float64
# Primary_Device                        object
# Exceeded_Recommended_Limit              bool
# Educational_to_Recreational_Ratio    float64
# Health_Impacts                        object
# Urban_or_Rural                        object
# dtype: object

# %%
df["Primary_Device"].unique()
# Out:
# array(['Smartphone', 'Laptop', 'TV', 'Tablet'], dtype=object)

# %%
df[df["Age"] > 12]
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 5      14  Female                      4.88     Smartphone
# 6      17    Male                      2.97             TV
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 2                           True                               0.32
# 3                          False                               0.39
# 5                           True                               0.44
# 6                          False                               0.48
# ...                          ...                                ...
# 9707                        True                               0.44
# 9708                        True                               0.40
# 9709                        True                               0.39
# 9710                        True                               0.43
# 9711                        True                               0.33
#
#                        Health_Impacts Urban_or_Rural
# 0              Poor Sleep, Eye Strain          Urban
# 2                          Poor Sleep          Urban
# 3                                 NaN          Urban
# 5                          Poor Sleep          Urban
# 6                                 NaN          Rural
# ...                               ...            ...
# 9707                       Poor Sleep          Urban
# 9708                       Poor Sleep          Rural
# 9709  Poor Sleep, Eye Strain, Anxiety          Rural
# 9710                       Poor Sleep          Urban
# 9711                          Anxiety          Urban
#
# [5305 rows x 8 columns]

# %%
df[df["Primary_Device"] == "Smartphone"]
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 4      12  Female                      5.89     Smartphone
# 5      14  Female                      4.88     Smartphone
# 12     12    Male                      4.59     Smartphone
# 14     15    Male                      6.15     Smartphone
# ...   ...     ...                       ...            ...
# 9703    9    Male                      6.62     Smartphone
# 9706    8    Male                      4.84     Smartphone
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 4                           True                               0.49
# 5                           True                               0.44
# 12                          True                               0.43
# 14                          True                               0.40
# ...                          ...                                ...
# 9703                        True                               0.48
# 9706                        True                               0.55
# 9707                        True                               0.44
# 9708                        True                               0.40
# 9709                        True                               0.39
#
#                        Health_Impacts Urban_or_Rural
# 0              Poor Sleep, Eye Strain          Urban
# 4                 Poor Sleep, Anxiety          Urban
# 5                          Poor Sleep          Urban
# 12                         Poor Sleep          Urban
# 14                         Poor Sleep          Urban
# ...                               ...            ...
# 9703                       Poor Sleep          Rural
# 9706                              NaN          Rural
# 9707                       Poor Sleep          Urban
# 9708                       Poor Sleep          Rural
# 9709  Poor Sleep, Eye Strain, Anxiety          Rural
#
# [4568 rows x 8 columns]

# %%
df.sort_values("Age", ascending=False)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 9683   18    Male                      5.11     Smartphone
# 2      18  Female                      3.73             TV
# 30     18    Male                      4.45     Smartphone
# 9693   18  Female                      7.54     Smartphone
# 9      18    Male                      3.24         Tablet
# ...   ...     ...                       ...            ...
# 9706    8    Male                      4.84     Smartphone
# 1535    8  Female                      1.21         Tablet
# 9690    8  Female                      5.57     Smartphone
# 9689    8    Male                      1.90         Tablet
# 9667    8  Female                      0.89         Tablet
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 9683                        True                               0.39
# 2                           True                               0.32
# 30                          True                               0.48
# 9693                        True                               0.36
# 9                           True                               0.48
# ...                          ...                                ...
# 9706                        True                               0.55
# 1535                       False                               0.40
# 9690                        True                               0.44
# 9689                       False                               0.57
# 9667                       False                               0.52
#
#                 Health_Impacts Urban_or_Rural
# 9683              Obesity Risk          Rural
# 2                   Poor Sleep          Urban
# 30                  Eye Strain          Urban
# 9693                Poor Sleep          Urban
# 9     Poor Sleep, Obesity Risk          Urban
# ...                        ...            ...
# 9706                       NaN          Rural
# 1535                       NaN          Rural
# 9690                Eye Strain          Rural
# 9689                       NaN          Urban
# 9667                       NaN          Urban
#
# [9712 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("/content/Indian_Kids_Screen_Time.csv")

screen_time_counts = df['Avg_Daily_Screen_Time_hr'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
plt.bar(screen_time_counts.index, screen_time_counts.values)

plt.xlabel("Average Daily Screen Time (hr)")
plt.ylabel("Count")
plt.title("Count of Records by Average Daily Screen Time")

plt.tight_layout()
plt.show()

# %%
plt.pie(df['Exceeded_Recommended_Limit'].value_counts(), labels=df['Exceeded_Recommended_Limit'].unique(), autopct='%1.1f%%')
plt.title('Exceed Recommended Limit')
plt.show()

# %%
age_counts = df['Age'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
plt.bar(age_counts.index, age_counts.values)

plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Count of Kids by Age")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['Avg_Daily_Screen_Time_hr'], alpha=0.5)

plt.xlabel("Age")
plt.ylabel("Average Daily Screen Time (hr)")
plt.title("Scatter Plot of Age vs. Average Daily Screen Time")

plt.grid(True)
plt.show()

# %%
ratio_counts = df['Educational_to_Recreational_Ratio'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
plt.bar(ratio_counts.index, ratio_counts.values)

plt.xlabel("Educational to Recreational Ratio")
plt.ylabel("Count")
plt.title("Count of Records by Educational to Recreational Ratio")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
df = pd.read_csv("/content/Indian_Kids_Screen_Time.csv")
df.iloc[2:8]
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
# 5   14  Female                      4.88     Smartphone
# 6   17    Male                      2.97             TV
# 7   10    Male                      2.74             TV
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
# 5                        True                               0.44
# 6                       False                               0.48
# 7                        True                               0.54
#
#         Health_Impacts Urban_or_Rural
# 2           Poor Sleep          Urban
# 3                  NaN          Urban
# 4  Poor Sleep, Anxiety          Urban
# 5           Poor Sleep          Urban
# 6                  NaN          Rural
# 7                  NaN          Urban

# %%
df.loc[:, ["Age", "Avg_Daily_Screen_Time_hr", "Primary_Device"]]
# Out:
#       Age  Avg_Daily_Screen_Time_hr Primary_Device
# 0      14                      3.99     Smartphone
# 1      11                      4.61         Laptop
# 2      18                      3.73             TV
# 3      15                      1.21         Laptop
# 4      12                      5.89     Smartphone
# ...   ...                       ...            ...
# 9707   17                      3.26     Smartphone
# 9708   17                      4.43     Smartphone
# 9709   16                      5.62     Smartphone
# 9710   17                      5.60             TV
# 9711   15                      6.12             TV
#
# [9712 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   object
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   object
#  7   Urban_or_Rural                     9712 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 540.7+ KB

# %%
df.describe()
# Out:
#                Age  Avg_Daily_Screen_Time_hr  \
# count  9712.000000               9712.000000
# mean     12.979201                  4.352837
# std       3.162437                  1.718232
# min       8.000000                  0.000000
# 25%      10.000000                  3.410000
# 50%      13.000000                  4.440000
# 75%      16.000000                  5.380000
# max      18.000000                 13.890000
#
#        Educational_to_Recreational_Ratio
# count                        9712.000000
# mean                            0.427226
# std                             0.073221
# min                             0.300000
# 25%                             0.370000
# 50%                             0.430000
# 75%                             0.480000
# max                             0.600000

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Indian_Kids_Screen_Time.csv")

# %%
sns.scatterplot(x="Educational_to_Recreational_Ratio", y="Avg_Daily_Screen_Time_hr", data=df)
# Out:
# <Axes: xlabel='Educational_to_Recreational_Ratio', ylabel='Avg_Daily_Screen_Time_hr'>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Indian_Kids_Screen_Time.csv")
df.fillna("None", inplace=True)

# %%
health_impacts_summary = df['Health_Impacts'].value_counts()
display(health_impacts_summary)
# Out:
# Health_Impacts
# None                                             3218
# Poor Sleep                                       2268
# Poor Sleep, Eye Strain                            979
# Eye Strain                                        644
# Poor Sleep, Anxiety                               608
# Poor Sleep, Obesity Risk                          452
# Anxiety                                           385
# Poor Sleep, Eye Strain, Anxiety                   258
# Obesity Risk                                      252
# Poor Sleep, Eye Strain, Obesity Risk              188
# Eye Strain, Anxiety                               135
# Eye Strain, Obesity Risk                          106
# Poor Sleep, Anxiety, Obesity Risk                  78
# Anxiety, Obesity Risk                              69
# Poor Sleep, Eye Strain, Anxiety, Obesity Risk      37
# Eye Strain, Anxiety, Obesity Risk                  35
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Indian_Kids_Screen_Time.csv")
df['Health_Impacts'].fillna("None", inplace=True)
display(df.isnull().sum())
# Out:
# /tmp/ipython-input-2647401656.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Health_Impacts'].fillna("None", inplace=True)
# Age                                  0
# Gender                               0
# Avg_Daily_Screen_Time_hr             0
# Primary_Device                       0
# Exceeded_Recommended_Limit           0
# Educational_to_Recreational_Ratio    0
# Health_Impacts                       0
# Urban_or_Rural                       0
# dtype: int64

# %%
df['Num_Health_Impacts'] = df['Health_Impacts'].apply(lambda x: 0 if x == 'None' else len(x.split(', ')))
display(df.head())
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural  Num_Health_Impacts
# 0  Poor Sleep, Eye Strain          Urban                   2
# 1              Poor Sleep          Urban                   1
# 2              Poor Sleep          Urban                   1
# 3                    None          Urban                   0
# 4     Poor Sleep, Anxiety          Urban                   2

# %%
df = pd.read_csv("/content/screen_time.csv")

# %%
df = pd.read_csv("/content/Indian_Kids_Screen_Time.csv")

# %%
import pandas as pd

# %%
average_screen_time_by_gender = df.groupby('Gender')['Average Screen Time (hours)'].mean()
display(average_screen_time_by_gender)
# Out:
# Gender
# Female                     2.915455
# Male                       3.070000
# Other/Prefer not to say    2.993636
# Name: Average Screen Time (hours), dtype: float64

# %%
average_screen_time_by_day_type = df.groupby('Day Type')['Average Screen Time (hours)'].mean()
display(average_screen_time_by_day_type)
# Out:
# Day Type
# Weekday    2.661111
# Weekend    3.324949
# Name: Average Screen Time (hours), dtype: float64

# %%
df = pd.read_csv("/content/Indian_Kids_Screen_Time.csv")
display(df.head())
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban
# 3                     NaN          Urban
# 4     Poor Sleep, Anxiety          Urban

# %%
average_metrics_by_gender = df.groupby('Gender')[['Avg_Daily_Screen_Time_hr', 'Educational_to_Recreational_Ratio']].mean()
display(average_metrics_by_gender)
# Out:
#         Avg_Daily_Screen_Time_hr  Educational_to_Recreational_Ratio
# Gender
# Female                  4.327021                           0.426694
# Male                    4.377754                           0.427740

# %%
import matplotlib.pyplot as plt
average_metrics_by_gender.plot(kind='bar', figsize=(10, 6))
plt.xlabel("Gender")
plt.ylabel("Average Value")
plt.title("Average Screen Time and Educational to Recreational Ratio by Gender")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The average daily screen time for females is approximately 4.33 hours, while for males it is approximately 4.38 hours.
# *   The educational to recreational screen time ratio is approximately 0.43 for both females and males.
#
# ### Insights or Next Steps
#
# *   The data suggests there is very little difference in average screen time and the educational to recreational screen time ratio between genders in this dataset.
# *   Further analysis could explore other factors influencing screen time and the educational to recreational ratio, such as age group or location.

# %%
import pandas as pd
import numpy as np

# %%
average_screen_time_by_day_type = df_screen_time.groupby('Day Type')['Average Screen Time (hours)'].mean()
display(average_screen_time_by_day_type)
# Out:
# Day Type
# Weekday    2.661111
# Weekend    3.324949
# Name: Average Screen Time (hours), dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.boxplot(x='Gender', y='Average Screen Time (hours)', data=df_screen_time)
plt.xlabel("Gender")
plt.ylabel("Average Screen Time (hours)")
plt.title("Box Plot of Average Screen Time by Gender")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(df_screen_time['Average Screen Time (hours)'], bins=20, edgecolor='black')
plt.xlabel("Average Screen Time (hours)")
plt.ylabel("Frequency")
plt.title("Distribution of Average Screen Time")
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_screen_time['Age'], df_screen_time['Average Screen Time (hours)'], alpha=0.5)
plt.xlabel("Age")
plt.ylabel("Average Screen Time (hours)")
plt.title("Scatter Plot of Age vs. Average Screen Time")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

average_screen_time_by_day_type.plot(kind='bar', figsize=(8, 5), color=['skyblue', 'lightcoral'])
plt.xlabel("Day Type")
plt.ylabel("Average Screen Time (hr)")
plt.title("Average Screen Time on Weekdays vs. Weekends")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# %%
df_screen_time = pd.read_csv("/content/screen_time.csv")
display(df_screen_time.head())
display(df_screen_time.columns)
# Out:
#    Age Gender Screen Time Type Day Type  Average Screen Time (hours)  \
# 0    5   Male      Educational  Weekday                         0.44
# 1    5   Male     Recreational  Weekday                         1.11
# 2    5   Male            Total  Weekday                         1.55
# 3    5   Male      Educational  Weekend                         0.50
# 4    5   Male     Recreational  Weekend                         1.44
#
#    Sample Size
# 0          500
# 1          500
# 2          500
# 3          500
# 4          500
# Index(['Age', 'Gender', 'Screen Time Type', 'Day Type',
#        'Average Screen Time (hours)', 'Sample Size'],
#       dtype='object')

# %%
average_screen_time_by_day_type = df_screen_time.groupby('Day Type')['Average Screen Time (hours)'].mean()
display(average_screen_time_by_day_type)
# Out:
# Day Type
# Weekday    2.661111
# Weekend    3.324949
# Name: Average Screen Time (hours), dtype: float64

# %%
df_screen_time = pd.read_csv("/content/screen_time.csv")
display(df_screen_time.head())
display(df_screen_time.columns)
# Out:
#    Age Gender Screen Time Type Day Type  Average Screen Time (hours)  \
# 0    5   Male      Educational  Weekday                         0.44
# 1    5   Male     Recreational  Weekday                         1.11
# 2    5   Male            Total  Weekday                         1.55
# 3    5   Male      Educational  Weekend                         0.50
# 4    5   Male     Recreational  Weekend                         1.44
#
#    Sample Size
# 0          500
# 1          500
# 2          500
# 3          500
# 4          500
# Index(['Age', 'Gender', 'Screen Time Type', 'Day Type',
#        'Average Screen Time (hours)', 'Sample Size'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Avg_Daily_Screen_Time_hr', hue='Urban_or_Rural', data=df, alpha=0.5)
plt.xlabel("Age")
plt.ylabel("Average Daily Screen Time (hr)")
plt.title("Scatter Plot of Age vs. Average Daily Screen Time by Urban/Rural Location")
plt.grid(True)
plt.show()

# %%
df = pd.read_csv("/content/Indian_Kids_Screen_Time.csv")

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Indian_Kids_Screen_Time.csv")
print("Missing values before filling:")
display(df.isnull().sum())

df['Health_Impacts'].fillna("None", inplace=True)

print("\nMissing values after filling:")
display(df.isnull().sum())
# Out:
# Missing values before filling:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                          0
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3218
# Urban_or_Rural                          0
# dtype: int64
# Missing values after filling:
# /tmp/ipython-input-1252230783.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Health_Impacts'].fillna("None", inplace=True)
# Age                                  0
# Gender                               0
# Avg_Daily_Screen_Time_hr             0
# Primary_Device                       0
# Exceeded_Recommended_Limit           0
# Educational_to_Recreational_Ratio    0
# Health_Impacts                       0
# Urban_or_Rural                       0
# dtype: int64

# %%
user_age = int(input("Enter your age: "))
user_gender = input("Enter your gender (Male/Female): ")
user_screen_time = float(input("Enter your average daily screen time in hours: "))
user_edu_recre_ratio = float(input("Enter your educational to recreational screen time ratio (e.g., 0.4): "))
user_primary_device = input("Enter your primary device (Smartphone/Laptop/TV/Tablet): ")
user_health_impacts = input("Enter any health impacts you experience (comma-separated, e.g., Poor Sleep, Eye Strain) or type 'None': ")

recommendations = get_screen_time_recommendations(user_age, user_gender, user_screen_time, user_edu_recre_ratio, user_primary_device, user_health_impacts)

print(f"\nRecommendations for you (Age: {user_age}, Gender: {user_gender}, Screen Time: {user_screen_time} hrs, Health Impacts: {user_health_impacts}):")
for rec in recommendations:
    print(f"- {rec}")
# Out:
# Enter your age: 8
# Enter your gender (Male/Female): Male
# Enter your average daily screen time in hours: 5
# Enter your educational to recreational screen time ratio (e.g., 0.4): 0.4
# Enter your primary device (Smartphone/Laptop/TV/Tablet): Smartphone
# Enter any health impacts you experience (comma-separated, e.g., Poor Sleep, Eye Strain) or type 'None': Poor Sleep
#
# Recommendations for you (Age: 8, Gender: Male, Screen Time: 5.0 hrs, Health Impacts: Poor Sleep):
# - Warning: Your screen time is 14.9% higher than the average (4.4 hrs) and may exceed recommended limits.
# - Consider reducing your overall screen time.
# - Be mindful of the reported health impacts and consider seeking professional advice if needed.
# - Avoid screens for at least an hour before bedtime to improve sleep quality.
# - For users of Smartphone, the most commonly observed health impact is 'Poor Sleep'.
# - The average daily screen time for users of Smartphone is approximately 4.4 hours.
# - The average screen time for kids aged 8 who are Male is approximately 4.1 hours.
# - For younger children, focus on educational and interactive content with parental guidance.
# - Be mindful of your smartphone usage duration and consider using blue light filters.

# %%
correlation_matrix = df.corr(numeric_only=True)
display(correlation_matrix)
# Out:
#                                         Age  Avg_Daily_Screen_Time_hr  \
# Age                                1.000000                  0.118328
# Avg_Daily_Screen_Time_hr           0.118328                  1.000000
# Exceeded_Recommended_Limit         0.159173                  0.664950
# Educational_to_Recreational_Ratio -0.488617                 -0.087552
#
#                                    Exceeded_Recommended_Limit  \
# Age                                                  0.159173
# Avg_Daily_Screen_Time_hr                             0.664950
# Exceeded_Recommended_Limit                           1.000000
# Educational_to_Recreational_Ratio                   -0.126643
#
#                                    Educational_to_Recreational_Ratio
# Age                                                        -0.488617
# Avg_Daily_Screen_Time_hr                                   -0.087552
# Exceeded_Recommended_Limit                                 -0.126643
# Educational_to_Recreational_Ratio                           1.000000

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Indian_Kids_Screen_Time.csv")
exceeded_counts = df['Exceeded_Recommended_Limit'].value_counts()
display(exceeded_counts)
# Out:
# Exceeded_Recommended_Limit
# True     8301
# False    1411
# Name: count, dtype: int64

# %%
average_metrics_by_gender = df.groupby('Gender')[['Avg_Daily_Screen_Time_hr', 'Educational_to_Recreational_Ratio']].mean()
display(average_metrics_by_gender)

average_metrics_by_device = df.groupby('Primary_Device')[['Avg_Daily_Screen_Time_hr', 'Educational_to_Recreational_Ratio']].mean()
display(average_metrics_by_device)

average_metrics_by_location = df.groupby('Urban_or_Rural')[['Avg_Daily_Screen_Time_hr', 'Educational_to_Recreational_Ratio']].mean()
display(average_metrics_by_location)

average_metrics_by_age = df.groupby('Age')[['Avg_Daily_Screen_Time_hr', 'Educational_to_Recreational_Ratio']].mean()
display(average_metrics_by_age)

average_metrics_by_health_impacts = df.groupby('Health_Impacts')[['Avg_Daily_Screen_Time_hr', 'Educational_to_Recreational_Ratio']].mean()
display(average_metrics_by_health_impacts)
# Out:
#         Avg_Daily_Screen_Time_hr  Educational_to_Recreational_Ratio
# Gender
# Female                  4.327021                           0.426694
# Male                    4.377754                           0.427740
#                 Avg_Daily_Screen_Time_hr  Educational_to_Recreational_Ratio
# Primary_Device
# Laptop                          4.459086                           0.399002
# Smartphone                      4.388925                           0.422077
# TV                              4.287752                           0.443703
# Tablet                          4.226005                           0.446005
#                 Avg_Daily_Screen_Time_hr  Educational_to_Recreational_Ratio
# Urban_or_Rural
# Rural                           4.373702                           0.427864
# Urban                           4.344123                           0.426960
#      Avg_Daily_Screen_Time_hr  Educational_to_Recreational_Ratio
# Age
# 8                    3.988925                           0.498070
# 9                    3.932181                           0.502746
# 10                   3.851425                           0.500924
# 11                   4.497263                           0.402610
# 12                   4.554348                           0.399654
# 13                   4.500967                           0.400440
# 14                   4.514821                           0.398862
# 15                   4.441725                           0.398843
# 16                   4.551781                           0.399452
# 17                   4.555397                           0.397280
# 18                   4.503976                           0.397833
#                                                Avg_Daily_Screen_Time_hr  \
# Health_Impacts
# Anxiety                                                        4.903403
# Anxiety, Obesity Risk                                          4.648841
# Eye Strain                                                     4.809301
# Eye Strain, Anxiety                                            5.081185
# Eye Strain, Anxiety, Obesity Risk                              4.993429
# Eye Strain, Obesity Risk                                       4.949811
# None                                                           3.213254
# Obesity Risk                                                   4.911151
# Poor Sleep                                                     4.955445
# Poor Sleep, Anxiety                                            4.906283
# Poor Sleep, Anxiety, Obesity Risk                              5.060641
# Poor Sleep, Eye Strain                                         4.883207
# Poor Sleep, Eye Strain, Anxiety                                4.911667
# Poor Sleep, Eye Strain, Anxiety, Obesity Risk                  4.548378
# Poor Sleep, Eye Strain, Obesity Risk                           4.818617
# Poor Sleep, Obesity Risk                                       5.015376
#
#                                                Educational_to_Recreational_Ratio
# Health_Impacts
# Anxiety                                                                 0.419974
# Anxiety, Obesity Risk                                                   0.409855
# Eye Strain                                                              0.420062
# Eye Strain, Anxiety                                                     0.420444
# Eye Strain, Anxiety, Obesity Risk                                       0.425714
# Eye Strain, Obesity Risk                                                0.431132
# None                                                                    0.441774
# Obesity Risk                                                            0.420635
# Poor Sleep                                                              0.421424
# Poor Sleep, Anxiety                                                     0.418092
# Poor Sleep, Anxiety, Obesity Risk                                       0.410641
# Poor Sleep, Eye Strain                                                  0.420266
# Poor Sleep, Eye Strain, Anxiety                                         0.415078
# Poor Sleep, Eye Strain, Anxiety, Obesity Risk                           0.402432
# Poor Sleep, Eye Strain, Obesity Risk                                    0.415160
# Poor Sleep, Obesity Risk                                                0.420907

# %%
print("Recommendation logic and types of recommendations defined.")
# Out:
# Recommendation logic and types of recommendations defined.

# %%
def get_screen_time_recommendations(age, gender, avg_daily_screen_time_hr, educational_to_recreational_ratio, primary_device, health_impacts):
    recommendations = []

    average_screen_time = df['Avg_Daily_Screen_Time_hr'].mean()

    if avg_daily_screen_time_hr > average_screen_time:
        percentage_higher = ((avg_daily_screen_time_hr - average_screen_time) / average_screen_time) * 100
        recommendations.append(f"Warning: Your screen time is {percentage_higher:.1f}% higher than the average ({average_screen_time:.1f} hrs) and may exceed recommended limits.")
        recommendations.append("Consider reducing your overall screen time.")
    elif avg_daily_screen_time_hr < average_screen_time:
        percentage_lower = ((average_screen_time - avg_daily_screen_time_hr) / average_screen_time) * 100
        recommendations.append(f"Your screen time is {percentage_lower:.1f}% lower than the average ({average_screen_time:.1f} hrs). Keep up the good habits!")
    else:
        recommendations.append("Your screen time is around the average.")

    average_edu_recre_ratio = df['Educational_to_Recreational_Ratio'].mean()
    if educational_to_recreational_ratio < average_edu_recre_ratio * 0.9:
        recommendations.append("Try to increase the proportion of educational content in your screen time.")

    if health_impacts != 'None':
        recommendations.append("Be mindful of the reported health impacts and consider seeking professional advice if needed.")
        if 'Poor Sleep' in health_impacts:
            recommendations.append("Avoid screens for at least an hour before bedtime to improve sleep quality.")
        if 'Eye Strain' in health_impacts:
            recommendations.append("Remember to take regular breaks during screen time to rest your eyes and body.")
        if 'Obesity Risk' in health_impacts:
            recommendations.append("Explore alternative activities like reading, sports, or spending time outdoors.")

    # Add device-specific health impact recommendations
    device_health_impacts = df[(df['Primary_Device'] == primary_device) & (df['Health_Impacts'] != 'None')]['Health_Impacts'].value_counts()
    if not device_health_impacts.empty:
        most_common_impact = device_health_impacts.index[0]
        recommendations.append(f"For users of {primary_device}, the most commonly observed health impact is '{most_common_impact}'.")

    # Add recommendation about average screen time for the primary device
    average_screen_time_for_device = df[df['Primary_Device'] == primary_device]['Avg_Daily_Screen_Time_hr'].mean()
    recommendations.append(f"The average daily screen time for users of {primary_device} is approximately {average_screen_time_for_device:.1f} hours.")

    # Add recommendation about average screen time for age group and gender
    average_screen_time_by_age_gender = df[(df['Age'] == age) & (df['Gender'] == gender)]['Avg_Daily_Screen_Time_hr'].mean()
    if not pd.isna(average_screen_time_by_age_gender):
        recommendations.append(f"The average screen time for kids aged {age} who are {gender} is approximately {average_screen_time_by_age_gender:.1f} hours.")


    if age <= 10 and avg_daily_screen_time_hr > 2:
         recommendations.append("For younger children, focus on educational and interactive content with parental guidance.")
    elif age > 10 and avg_daily_screen_time_hr > 4:
        recommendations.append("Consider setting screen time limits and encouraging a balance with other activities.")

    if primary_device == 'Smartphone':
        recommendations.append("Be mindful of your smartphone usage duration and consider using blue light filters.")


    return recommendations

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The 'Health\_Impacts' column initially had 3218 missing values, which were successfully filled with "None".
# *   Average daily screen time and educational to recreational ratio are very similar across genders and urban/rural locations.
# *   Laptop users have the highest average daily screen time.
# *   Average daily screen time generally increases with age from 8 to 18.
# *   The educational to recreational ratio decreases significantly in older age groups (11-18) compared to younger ones (8-10).
# *   Individuals reporting any health impact generally have significantly higher average daily screen time compared to those reporting "None".

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Indian_Kids_Screen_Time.csv")

# %%
# Filter only those who have NOT exceeded
within_limit = df[df['Exceeded_Recommended_Limit'] == False]
within_limit.sort_values(by=['Age', 'Avg_Daily_Screen_Time_hr'], ascending=[True, False])
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 2161    8  Female                      2.00         Tablet
# 6706    8    Male                      1.99     Smartphone
# 7191    8    Male                      1.98             TV
# 1644    8  Female                      1.95         Tablet
# 3620    8    Male                      1.95     Smartphone
# ...   ...     ...                       ...            ...
# 7271   18    Male                      1.71     Smartphone
# 3322   18  Female                      1.69             TV
# 7920   18    Male                      1.61     Smartphone
# 9676   18    Male                      0.86     Smartphone
# 8217   18    Male                      0.47             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 2161                       False                               0.41
# 6706                       False                               0.53
# 7191                       False                               0.43
# 1644                       False                               0.51
# 3620                       False                               0.51
# ...                          ...                                ...
# 7271                       False                               0.46
# 3322                       False                               0.38
# 7920                       False                               0.34
# 9676                       False                               0.32
# 8217                       False                               0.34
#
#      Health_Impacts Urban_or_Rural
# 2161            NaN          Rural
# 6706            NaN          Urban
# 7191            NaN          Urban
# 1644            NaN          Urban
# 3620            NaN          Rural
# ...             ...            ...
# 7271            NaN          Urban
# 3322            NaN          Rural
# 7920            NaN          Rural
# 9676            NaN          Urban
# 8217            NaN          Urban
#
# [1411 rows x 8 columns]

# %%
above_limit = df[df['Exceeded_Recommended_Limit'] == True]
above_limit.sort_values(by=['Age', 'Avg_Daily_Screen_Time_hr'], ascending=[True, True])
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 8152    8  Female                      2.01     Smartphone
# 356     8    Male                      2.02     Smartphone
# 696     8  Female                      2.03             TV
# 3480    8  Female                      2.03             TV
# 959     8    Male                      2.04             TV
# ...   ...     ...                       ...            ...
# 9693   18  Female                      7.54     Smartphone
# 4379   18  Female                      7.61             TV
# 5220   18    Male                      7.69     Smartphone
# 350    18    Male                      7.75         Tablet
# 5699   18  Female                      8.01     Smartphone
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 8152                        True                               0.60
# 356                         True                               0.57
# 696                         True                               0.47
# 3480                        True                               0.53
# 959                         True                               0.54
# ...                          ...                                ...
# 9693                        True                               0.36
# 4379                        True                               0.39
# 5220                        True                               0.30
# 350                         True                               0.34
# 5699                        True                               0.50
#
#                 Health_Impacts Urban_or_Rural
# 8152                       NaN          Urban
# 356                        NaN          Urban
# 696                        NaN          Rural
# 3480                       NaN          Urban
# 959                        NaN          Urban
# ...                        ...            ...
# 9693                Poor Sleep          Urban
# 4379  Poor Sleep, Obesity Risk          Rural
# 5220                       NaN          Urban
# 350                        NaN          Urban
# 5699                Poor Sleep          Urban
#
# [8301 rows x 8 columns]

# %%
min_screen_time_above_limit = above_limit['Avg_Daily_Screen_Time_hr'].min()
max_screen_time_within_limit = within_limit['Avg_Daily_Screen_Time_hr'].max()

print(f"Minimum average daily screen time for those who exceeded the limit: {min_screen_time_above_limit:.2f} hrs")
print(f"Maximum average daily screen time for those within the limit: {max_screen_time_within_limit:.2f} hrs")
# Out:
# Minimum average daily screen time for those who exceeded the limit: 2.01 hrs
# Maximum average daily screen time for those within the limit: 3.00 hrs

# %%
average_ratio_above_limit = above_limit['Educational_to_Recreational_Ratio'].mean()
average_ratio_within_limit = within_limit['Educational_to_Recreational_Ratio'].mean()

print(f"Average Educational to Recreational Ratio for those who exceeded the limit: {average_ratio_above_limit:.2f}")
print(f"Average Educational to Recreational Ratio for those within the limit: {average_ratio_within_limit:.2f}")
# Out:
# Average Educational to Recreational Ratio for those who exceeded the limit: 0.42
# Average Educational to Recreational Ratio for those within the limit: 0.45

# %%
health_impacts_above_limit_counts = above_limit[above_limit['Health_Impacts'] != 'None']['Health_Impacts'].value_counts()
health_impacts_within_limit_counts = within_limit[within_limit['Health_Impacts'] != 'None']['Health_Impacts'].value_counts()

print("Health Impacts for those who exceeded the recommended limit (excluding 'None'):")
display(health_impacts_above_limit_counts)

print("\nHealth Impacts for those within the recommended limit (excluding 'None'):")
display(health_impacts_within_limit_counts)
# Out:
# Health Impacts for those who exceeded the recommended limit (excluding 'None'):
# Health_Impacts
# Poor Sleep                                       2268
# Poor Sleep, Eye Strain                            979
# Eye Strain                                        644
# Poor Sleep, Anxiety                               608
# Poor Sleep, Obesity Risk                          452
# Anxiety                                           385
# Poor Sleep, Eye Strain, Anxiety                   258
# Obesity Risk                                      252
# Poor Sleep, Eye Strain, Obesity Risk              188
# Eye Strain, Anxiety                               135
# Eye Strain, Obesity Risk                          106
# Poor Sleep, Anxiety, Obesity Risk                  78
# Anxiety, Obesity Risk                              69
# Poor Sleep, Eye Strain, Anxiety, Obesity Risk      37
# Eye Strain, Anxiety, Obesity Risk                  35
# Name: count, dtype: int64
# Health Impacts for those within the recommended limit (excluding 'None'):
# Series([], Name: count, dtype: int64)

# %%
print("Demographics for those who exceeded the recommended limit:")
display(above_limit['Age'].value_counts().sort_index())
display(above_limit['Gender'].value_counts())
display(above_limit['Primary_Device'].value_counts())
display(above_limit['Urban_or_Rural'].value_counts())

print("\nDemographics for those within the recommended limit:")
display(within_limit['Age'].value_counts().sort_index())
display(within_limit['Gender'].value_counts())
display(within_limit['Primary_Device'].value_counts())
display(within_limit['Urban_or_Rural'].value_counts())
# Out:
# Demographics for those who exceeded the recommended limit:
# Age
# 8     684
# 9     648
# 10    639
# 11    777
# 12    782
# 13    815
# 14    811
# 15    769
# 16    798
# 17    818
# 18    760
# Name: count, dtype: int64
# Gender
# Male      4276
# Female    4025
# Name: count, dtype: int64
# Primary_Device
# Smartphone    3949
# TV            2085
# Laptop        1275
# Tablet         992
# Name: count, dtype: int64
# Urban_or_Rural
# Urban    5859
# Rural    2442
# Name: count, dtype: int64
# Demographics for those within the recommended limit:
# Age
# 8     228
# 9     237
# 10    238
# 11     89
# 12     85
# 13     95
# 14     85
# 15     95
# 16     78
# 17    101
# 18     80
# Name: count, dtype: int64
# Gender
# Female    745
# Male      666
# Name: count, dtype: int64
# Primary_Device
# Smartphone    619
# TV            402
# Tablet        232
# Laptop        158
# Name: count, dtype: int64
# Urban_or_Rural
# Urban    992
# Rural    419
# Name: count, dtype: int64
